# %%
import pandas as pd
import plotly.graph_objects as go

# %%
file_names=["/content/gdrive/MyDrive/dataset_battery/SNL_18650_LFP_15C_0-100_0.5-1C_a_timeseries.csv",
            '/content/gdrive/MyDrive/dataset_battery/SNL_18650_LFP_15C_0-100_0.5-1C_b_timeseries.csv',
            '/content/gdrive/MyDrive/dataset_battery/SNL_18650_LFP_15C_0-100_0.5-2C_a_timeseries.cvs',
            '/content/gdrive/MyDrive/dataset_battery/SNL_18650_LFP_15C_0-100_0.5-2C_b_timeseries.cvs',
            '/content/gdrive/MyDrive/dataset_battery/SNL_18650_LFP_15C_0-100_0.5-1C_a_timeseries.cvs',
            '/content/gdrive/MyDrive/dataset_battery/SNL_18650_LFP_25C_0-100_0.5-1C_c_timeseries.csv',
            '/content/gdrive/MyDrive/dataset_battery/SNL_18650_LFP_25C_0-100_0.5-3C_b_timeseries.csv',
            '/content/gdrive/MyDrive/dataset_battery/SNL_18650_LFP_25C_0-100_0.5-3C_c_timeseries.csv',
            '/content/gdrive/MyDrive/dataset_battery/SNL_18650_LFP_25C_0-100_0.5-3C_d_cycle_data.csv',
            '/content/gdrive/MyDrive/dataset_battery/SNL_18650_LFP_25C_0-100_0.5-3C_d_timeseries.csv',
            ]

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
df_15_1_a=pd.read_csv(file_names[0])

# %%
#df_15_1_a=pd.read_csv(file_names[1])

# %%
df_15_1_a[680-2:1424-2]
# Out:
#                        Date_Time  Test_Time (s)  Cycle_Index  Current (A)  \
# 678   2018-02-01 12:20:26.487212       8306.487          1.0       -0.550
# 679   2018-02-01 12:20:30.137545       8310.137          1.0       -0.549
# 680   2018-02-01 12:20:34.567833       8314.567          1.0       -0.550
# 681   2018-02-01 12:20:39.715766       8319.715          1.0       -0.549
# 682   2018-02-01 12:20:45.799661       8325.799          1.0       -0.550
# ...                          ...            ...          ...          ...
# 1417  2018-02-01 14:18:45.450017      15405.450          1.0        0.000
# 1418  2018-02-01 14:19:45.477682      15465.477          1.0        0.000
# 1419  2018-02-01 14:20:45.505349      15525.505          1.0        0.000
# 1420  2018-02-01 14:21:45.532995      15585.532          1.0        0.000
# 1421  2018-02-01 14:22:45.311114      15645.311          1.0        0.000
#
#       Voltage (V)  Charge_Capacity (Ah)  Discharge_Capacity (Ah)  \
# ...

# %% [markdown]
# Ток заряда

# %%
import plotly.express as px


fig = px.line(df_15_1_a[:678], x='Test_Time (s)', y="Current (A)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Емкость при зарядке

# %%
fig = px.line(df_15_1_a[:678], x='Test_Time (s)', y="Charge_Capacity (Ah)")
#fig = px.line(df_15_1_a[1424-2:678], x='Test_Time (s)', y="Charge_Capacity (Ah)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Ток разряда

# %%
fig = px.line(df_15_1_a[680-2:1424-2], x='Test_Time (s)', y="Current (A)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Емкость при разрядке

# %%
fig = px.line(df_15_1_a[680-2:1424-2], x='Test_Time (s)', y="Discharge_Capacity (Ah)")
#fig = px.line(df_15_1_a[465130-2:465886-2], x='Test_Time (s)', y="Discharge_Capacity (Ah)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data_charge_cap_deegrad=df_15_1_a.loc[df_15_1_a['Discharge_Capacity (Ah)'] == 0]

# %%
data_charge_cap_deegrad[470:471]
# Out:
#                       Date_Time  Test_Time (s)  Cycle_Index  Current (A)  \
# 470  2018-02-01 11:19:56.685046       4676.685          1.0         0.55
#
#      Voltage (V)  Charge_Capacity (Ah)  Discharge_Capacity (Ah)  \
# 470        3.428                 0.705                      0.0
#
#      Charge_Energy (Wh)  Discharge_Energy (Wh)  Environment_Temperature (C)  \
# 470                2.37                    0.0                       15.117
#
#      Cell_Temperature (C)
# 470                16.172

# %%
for i in range(1,4500):
    d=data_charge_cap_deegrad.loc[data_charge_cap_deegrad['Cycle_Index']== float(i)]
    if (len(d))>70:
        print(i, len(d))
# Out:
# 1 679
# 2 703
# 3 702
# 503 737
# 504 697
# 505 697
# 508 674
# 509 700
# 510 703
# 1010 731
# 1011 691
# 1012 693
# 1014 671
# 1015 692
# 1016 692
# 1516 726
# 1517 686
# 1518 688
# 1520 667
# 1521 691
# 1522 692
# 1979 81
# 1980 658
# 1981 685
# 1982 685
# 2187 531
# 2188 678
# 2189 680
# 2483 721
# 2484 678
# 2485 680
# 2487 659
# 2488 680
# 2489 681
# 3030 713
# 3031 671
# 3032 673
# 3034 651
# 3035 674
# 3036 675
# 3536 705
# 3537 665
# 3538 666
# 3540 644
# 3541 670
# 3542 670
# 4042 699
# 4043 659
# 4044 660
# 4046 640
# 4047 662
# 4048 664

# %%
fig = go.Figure()

# %%
for i in range(1,4500, 100):
    data=data_charge_cap_deegrad.loc[data_charge_cap_deegrad['Cycle_Index']== float(i)]
    fig.add_trace(go.Scatter(data,x='', y=high_2014, name='High 2014',
                         line=dict(color='firebrick', width=4)))
